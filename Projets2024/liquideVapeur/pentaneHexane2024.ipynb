# %% [markdown]
# # Etude de l'équilibre liquide/vapeur d'un mélange n-pentane/n-hexane - V2024
#
#
# ## Introduction
#
# Pour un corps pur comme l'eau par exemple, on sait que pour une pression donnée, on ne peut avoir simultanément la phase liquide et la phase gaz qu'à une unique température. A la pression atmosphérique, cette température est de 100 °C.
#
# Pour un mélange de liquide, ce n'est plus le cas : la température d'ébullition à pression donnée n'est pas unique et elle dépend de la composition du mélange liquide. De plus, la composition du mélange vapeur en équilibre avec ce mélange liquide n'a pas la même composition que ce dernier : la phase vapeur est plus riche en composé le plus volatil que ne l'est la phase liquide.
#
# Prenons l'exemple d'un mélange benzène/toluène illustré dans la figure ci-dessous pour une pression de 1 atm. L'axe des abcisses ($z_A$) représente la fraction molaire de toluène dans le mélange liquide ou vapeur. L'axe des ordonnées correspond à la température.

# %% [markdown]
# ![eqBenzeneToluene.png](attachment:eqBenzeneToluene.png)

# %% [markdown]
# Que peut-on lire sur cette figure et comment l'exploiter ?
# - Il y a deux courbes, l'une appelée courbe de rosée et l'autre courbe d'ébullition. Au-dessus de la courbe de rosée, le mélange est entièrement en phase vapeur. Sous la courbe d'ébullition, le mélange est entièrement en phase vapeur. Entre les 2 courbes, il y a simultanément une phase gaz et une phase liquide.
# - Pour $x=0$ (benzène pur), on voit que la température d'ébullition du benzène pur est 353.2 K.
# - Pour $x=1$ (toluène pur), la température d'ébullition est 383.7 K.
# - Plaçons nous maintenant à une composition du liquide de 0,4 molaire en toluène à 350 K, il y a alors seulement du liquide. En augmentant la température, on lit sur la courbe d'ébullition que la première bulle de vapeur apparaît à T = 362 K. En traçant une horizontale à cette température, on lit alors sur la courbe de rosée que la composition de cette bulle est d'environ 0,18 molaire.
#
# On pourrait raconter plein d'autres choses autour de cette courbe, mais nous n'irons pas au-delà de cette compréhension sommaire pour ce projet.
#
# Pour votre culture générale, ces principes théoriques sont ceux utilisés pour des procédés tel que la distillation par exemple : pour faire de l'alcool, il faut connaître l'évolution de la composition des phases liquide et vapeur en fonction de la température. Il en va de même pour obtenir de l'essence, du kérosène ou du gazole depuis du pétrole brut.
#
# **Le but de projet est d'étudier l'équilibre liquide/vapeur d'un mélange n-pentane/n-hexane à à la pression atmosphérique 𝑃=760 mmHg.**
#
#
#
# ## Notations
#
# **Fractions molaires dans la phase liquide** :
# $x_5$ : fraction molaire du pentane dans le liquide
# $x_6$ : fraction molaire de l'hexane dans le liquide
#
#
# **Fractions molaires dans la phase gaz** :
# $y_5$ : fraction molaire du pentane dans le gaz
# $y_6$ : fraction molaire de l'hexane dans le gaz
#
# **Pressions de vapeur saturante** :
# $P^{\mathrm{sat}}_{\mathrm{pentane}}$ : Pressions de vapeur saturante du pentane
# $P^{\mathrm{sat}}_{\mathrm{hexane}}$ : Pressions de vapeur saturante de l'hexane

# %% [markdown]
# ## 1. Lecture des données expérimentales de pression de vapeur saturante
#
# Le fichier dataH6P5.csv comprend 3 colonnes. La première contient des températures en °C. Les deux suivantes contiennent respectivement les pressions de vapeur saturante en mmHg de l'hexane et du pentane pour chaque température de la première colonne. Dans ce projet, vous n'avez pas à faire de conversion d'unités.
#
# 1. Faire le nécessaire pour que le contenu de chaque colonne soit mis en mémoire dans des variables : Tdata, H6data et P5data.
#
# 1. Tracer sur la même figure les courbes expérimentales représentant le logarithme décimal de la pression de vapeur saturante en fonction de la température avec des triangles verts pour l'hexane et des croix magenta pour le pentane. Légender proprement votre figure.

# %%
#A compléter

# %% [markdown]
# # 2. Ajustement des données expérimentales pour les corps purs à un modèle
#
# La pression de vapeur saturante d'un **corps pur** répond à des relations du type
# $$\Large log_{10}(P^{\mathrm{sat}})=a+\dfrac{b}{c+T} $$
#
# où $P^{\mathrm{sat}}$ est la pression de vapeur saturante et $T$ la température. Les paramètres $a$, $b$ et $c$ dépendent du corps pur considéré.
#
# A partir des données expérimentales fournies, calculer les paramètres $a_5$, $b_5$ et $c_5$ correspondant au modèle pour le pentane et $a_6$, $b_6$ et $c_6$ correspondant au modèle pour l'hexane.
# Votre expérience d'expert en pression de vapeur saturante vous indique que de bonnes valeurs pour initialiser les processus de recherche des 3 paramètres sont 100, -1000 et 200 respectivement pour $a$, $b$ et $c$.
#
# Afficher la valeur de ces paramètres.
#
# Indice : voir la fiche de cours sur l'**ajustement de modèle**

# %%
#A compléter
# Out:
# 6.586311252000146 -936.795063926138 216.6835173451992
# 6.551339886144461 -1006.949669190585 223.2164898538192

# %% [markdown]
# Tracer sur le même graphe, les données expérimentales et leur ajustement en respectant les mêmes couleurs que précédemment (rouge pour le pentane et bleu pour l'hexane). Afficher également les légendes correspondantes.

# %%
#A compléter

# %% [markdown]
# ## 3. Etude de l'évolution de la température d'ébullition d'un mélange hexane/pentane en fonction de sa composition.
#
# Dans la suite de ce projet, nous considérerons un mélange liquide d'hexane et de pentane.
#
# Le but est ici de déterminer la température d'ébullition d'un mélange hextane/pentane. La température d'ébullition est celle pour laquelle on a:
# $$ 1 = x_5P^{*\mathrm{sat}}_{\mathrm{pentane}}+x_6P^{*\mathrm{sat}}_{\mathrm{hexane}}$$
# avec $P^{*\mathrm{sat}}_{\mathrm{pentane}}=P^{\mathrm{sat}}_{\mathrm{pentane}}/P_{\mathrm{total}}$ et $P^{*\mathrm{sat}}_{\mathrm{hexane}}=P^{\mathrm{sat}}_{\mathrm{hexane}}/P_{\mathrm{total}}$.
#
# Dans le cas présent, $ P_{\mathrm{total}}= 760 $ mmHg, c'est à dire la pression atmosphérique.
#
# Dans cette partie, il faut demander à l'utilisateur la valeur de $x_5$. Elle est forcément comprise en 0 et 1, c'est une fraction molaire !
# Faîtes alors le calcul de la température d'ébullition pour un mélange équimolaire : $x_5=0.5$. Connaissant la valeur de $x_5$, celle de $x_6$ peut être facilement calculée d'après la relation $x_5+x_6=1$.
#
# *Indice* : A la question précédente, vous avez trouvé les coefficients d'ajustement de modèles permettant de calculer la pression saturante du pentane et de l'hexane en fonction de la température. Vous êtes donc en capacité de calculer les valeurs des fonctions $P^{\mathrm{sat}}_{\mathrm{pentane}}(T)$ et $P^{\mathrm{sat}}_{\mathrm{hexane}}(T)$ pour n'importe quelle température. Dans cette question, vous cherchez donc à **résoudre l'équation non-linéaire**
# $$ 1 = x_5P^{*\mathrm{sat}}_{\mathrm{pentane}}(T) + x_6P^{*\mathrm{sat}}_{\mathrm{hexane}}(T)$$ dont l'inconnue est la température $T$.

# %%
#A compléter

# %% [markdown]
# Maintenant que vous savez calculer la valeur de la température d'ébullition d'un mélange contenant une fraction molaire donnée $x_5$ de pentane, on vous demande de tracer l'évolution de la température d'ébullition en fonction de $x_5$ pour $x_5 \in [0,1]$. C'est précisément la courbe d'ébullition pour le mélange hexane/pentane équivalente à celle présentée pour la mélange benzène/toluène en introduction.
#
# *Indice* : Mettre dans un tableau x5Tab des valeurs de $x_5$ comprises entre 0 et 1. Vous pouvez prendre 100 valeurs par exemple. Pour chacune des valeurs du tableau x5Tab, vous calculerez une valeur de la température d'ébullition que vous ajouterez à une liste (ou un tableau au choix) que vous nommerez TEbull (Vous avez déjà fait ce type de travail consistant à ajouter des valeurs à une liste ou tableau dans le TP1 sur les listes).
# Vous êtes alors en mesure de tracer la température d'ébullition du mélange en fonction de $x_5$.

# %%
#A compléter

# %% [markdown]
# ## 4. Tracé de la fraction molaire en phase gaz en fonction de celle en phase liquide.
#
#
# Pour certaines opérations du génie des procédés physico chimiques, il peut être utile de tracer l'évolution de $x_5$ en fonction de $y_5$.
#
# Connaissant la température d'ébullition d'un mélange liquide de composition $x_5$ , on peut calculer la fraction molaire de pentane dans la phase gaz :
# $$ y_5=\dfrac{x_5P^{\mathrm{sat}}_5}{760}$$
#
# Tracer le graphe représentant $x_5$ en fonction de $y_5$
#
# *Indices* : Vous avez déjà un tableau contenant des valeurs de $x_5$ allant de 0 à 1. Pour chacune de ces valeurs de $x_5$, vous connaissez la température d'ébullition que vous avez déjà mise dans le tableau TEbull (question 3). Or à la question 2, grâce à l'ajustement, vous savez calculer pour n'importe quelle température du mélange liquide $P^{\mathrm{sat}}_5$.

# %%
#A compléter

# %% [markdown]
# # 5. Tracé des courbes d'ébullition et de rosée
#
# Il vous faut représenter sur une même figure les courbes de rosée et d'ébullition.
#
# *Indice*: En 3, vous avez déjà tracé la courbe d'ébullition. En 4, vous avez représenté la composition $x_5$ en fonction de  la composition de la première bulle de la phase vapeur $y_5$. Il faut donc vous aider du travail effectué en 4 pour tracer la courbe de rosée.

# %%
#A compléter

# %% [markdown]
# # 6. Trouver la fraction liquide en équilibre pour une composition donnée de la phase gaz.
#
# Connaissant la fraction $y_5=0.5$ dans la phase gaz, trouver la valeur de $x_5$ dans le mélange liquide en équilibre avec cette phase gaz.
#
# *Indice* : Ce problème revient à trouver la température, qui est la **solution de l'équation non-linéaire**
# $$ P_{\mathrm{total}}= x_5(T)P^{\mathrm{sat}}_5(T)+(1-x_5(T))P^{\mathrm{sat}}_6(T)$$
# tout en sachant que dans cette équation $x_5$ dépend lui-même de la température suivant la relation
# $$x_5(T)=\dfrac{760y_5(T)}{P^{\mathrm{sat}}_5(T)}$$.
# On rappelle que les fonctions $P^{\mathrm{sat}}_5(T)$ et $P^{\mathrm{sat}}_6(T)$ sont connues via les modèles ajustés de la question 2.

# %%
#A compléter
