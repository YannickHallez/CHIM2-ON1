# %%
# ##########################################################################################
# 
# run this cell before using the rest of the notebook
# 
# remove it if you run this notebook outside the CHIM2-ON1 distribution #
# 
# ##########################################################################################

import os
import sys

cwd0 = './config/'
sys.path.append(cwd0)

import visualID as vID
from visualID import color
vID.init(cwd0)
# Out:
# <style>
# h1, h2, h3, h4, h5, h6 {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: bold;
# }
# body {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: 200;
# }
# h1 {
#   border: 0 solid #333;
#   padding: 30px ;
#   color: white;
#   background: #b11d01;
#   text-align: center;
# }
# h2 {
#   border: 3px solid #333;
#   padding: 18px ;
#   color: #b11d01;
#   background: #ffffff;
#   text-align: center;
# }
# h3 {
#   border: 0 solid #333;
#   padding: 12px ;
#   color: #000000;
#   background: #c1c1c1;
#   text-align: left;
# }
# h4 {
#   border: 0 solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #d9fffc;
#   text-align: left;
# }
# h5 {
#   border: 1px solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #ffffff;
#   text-align: left;
# }
# .warn {
#     background-color: #fcf2f2;
#     border-color: #dFb5b4;
# ...

# %% [markdown]
# # Table of contents
#
# ### Course 1: Creating and using variables, lists and tables
# - [notebook. First steps with Python](./Choisir_Python_en.ipynb)
# - [notebook. Variables](./Les_Variables_en.ipynb)
# - [notebook. The module structure](./Les_Modules_en.ipynb)
# - [notebook. Lists](./listes_en.ipynb)
# - [notebook. `numpy` arrays](./tableaux_en.ipynb)
#
# ### Course 2: Control Structures and Loops
#
# - [notebook. Tests](./Conditions_en.ipynb)
# - [notebook. Conditional structures](./Conditions_en.ipynb)
# - [notebook. Loops](./Boucles_en.ipynb)
#
# <div class="warn">
#
# **Laboratory topics courses 1 & 2**
#
# **<span style="color:red">Don't forget to rename each TP notebook after loading it (Menu `File > Rename` of jupyter-notebook or jupyter-lab)!</span>**
#
# - [notebook lab 1](./Exercices/TP1-vierge_en.ipynb)
# - [notebook lab 2](./Exercices/TP2-vierge_en.ipynb)
#
# </div>
#
# ### Course 3: The main scientific modules for reading and representing data
#
# - [notebook. Data representation part 1](./Graphes_en.ipynb)
# - [notebook. Data representation part 2](./Graphes_multi_en.ipynb)
# - [notebook. Data reading and writing](./Fichiers_en.ipynb)
#
# ### Course 4: Data processing and modeling
#
# - [notebook. Functions](./Les_Fonctions_en.ipynb)
# - [notebook. Model fitting](./Ajustement_en.ipynb)
#
# <div class="warn">
#
# **Laboratory topics courses 3 & 4**
#
# **<span style="color:red">Don't forget to rename each TP notebook after loading it (Menu `File > Rename` of jupyter-notebook or jupyter-lab)!</span>**
#
# - [notebook lab 3](./Exercices/TP3-vierge_en.ipynb)
# - [notebook lab 4](./Exercices/TP4-vierge_en.ipynb)
#
# </div>
#
# ### Course 5: Calculation and resolution tools
#
# - [notebook. Integration](./Les_Integrales_en.ipynb)
# - [notebook. Equation solving (non-differential)](./Resolution_EA_en.ipynb)
# - [notebook. Differential equation solving](./ode.ipynb)
#
# <div class="warn">
#
# **Laboratory topics course 5**
#
# **<span style="color:red">Don't forget to rename each TP notebook after loading it (Menu `File > Rename` of jupyter-notebook or jupyter-lab)!</span>**
#
# - [notebook lab 5](./Exercices/TP5-vierge_en.ipynb)
# - [notebook lab 6](./Exercices/TP6-vierge_en.ipynb)
#
# </div>
#
# ### Course 6: Statistical data processing (data science for beginners)
#
# [Lien vers la page de cette thématique](./DS4B-TOC.ipynb)

# %%
# ##########################################################################################
# delete this cell if you run this notebook outside of the CHIM2-ON1 distribution #
# ##########################################################################################

vID.end(cwd0)
# Out:
# **Fin à:** Tuesday 22 November 2022, 16:41:31
# **Durée:** 00:00:01 884ms
# <p style="text-align: center"><img width="800px" src="./config/svg/logoFin.svg" style="margin-left:auto; margin-right:auto"/></p>
