# %%
# ##########################################################################################
# 
# run this cell before using the rest of the notebook
# 
# remove it if you run this notebook outside the CHIM2-ON1 distribution #
# 
# ##########################################################################################

import os
import sys

cwd0 = "../config/"
sys.path.append(cwd0)
                            
import visualID as vID
from visualID import color
vID.init(cwd0)
# Out:
# <style>
# h1, h2, h3, h4, h5, h6 {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: bold;
# }
# body {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: 200;
# }
# h1 {
#   border: 0 solid #333;
#   padding: 30px ;
#   color: white;
#   background: #b11d01;
#   text-align: center;
# }
# h2 {
#   border: 3px solid #333;
#   padding: 18px ;
#   color: #b11d01;
#   background: #ffffff;
#   text-align: center;
# }
# h3 {
#   border: 0 solid #333;
#   padding: 12px ;
#   color: #000000;
#   background: #c1c1c1;
#   text-align: left;
# }
# h4 {
#   border: 0 solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #d9fffc;
#   text-align: left;
# }
# h5 {
#   border: 1px solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #ffffff;
#   text-align: left;
# }
# .warn {
#     background-color: #fcf2f2;
#     border-color: #dFb5b4;
# ...

# %% [markdown]
# # TP3. Exercises on reading and representing data
#
# ## Exercise 1. Draw curves quickly
#
# Trace as simply as possible the curve of $\sin(x)$ between 0 and 2$\pi$.

# %% [markdown]
# Draw in a dotted line the curve of $e^x$ between -1 and 1.

# %% [markdown]
# Draw the curve of $\frac{\sin(x)}{x}$ between $-\pi$ and $\pi$ with a red colored curve.

# %% [markdown]
# Plot the curve $x^4\ln(x)$ between 1 and 10. Add the "x" label on the x-axis and the "value" label on the y-axis.

# %% [markdown]
# On the same figure, draw the curves of $\sin(x)$ and $\cos(x)$ between -$\pi$ and 𝜋. The first will be blue, and the second green. Add a caption mentioning "sin x" and "cos x".

# %% [markdown]
# ## Exercise 2. Load and plot data quickly
#
# Load the data contained in the MysteryCurve.dat file and plot it with a solid red line.

# %%
# To be completed...

# loading:

# trace :

# %% [markdown]
# ## Exercise 3. Produce a quality graph.
#
# Reproduce the graphic below with all its elements (title, labels, colors, legend, etc.). The x-axis goes to $4\pi$.
# ![](Graph_to_reproduce.png)

# %%
# Complete

# %% [markdown]
# ## Exercise 4. Load, plot and analyze data from a titration to deduce the dissociation constant of an acid.
#
# A 0.1 M acetic acid solution is titrated using 0.2 M sodium hydroxide. The reaction is
#
# $\mathrm{CH_3CO_2H+OH^{−} \rightarrow CH_3CO^-_2 + H_2O}$
#
# The initial volume of acid is 50 mL. An automatic titrator slowly and gradually adds 25 mL of sodium hydroxide and records the pH during this addition. At the end of the experiment, the device saved the data in the `Titrage.csv` file in the form of a first column for the added volume and a second column for the pH.
#
# The goal of the exercise is to deduce the pKa from these data. To do this, follow the steps below.
#
# ### Data loading/representation
#
# Load and plot the data on a graph giving pH versus added volume of sodium hydroxide. The pH will be stored in a `pH` table and the volume of soda added in a `Vs` table.
#
# Place the axis labels as well as the legend. The curve will be represented with crosses.

# %%
# Loading

# Graph

# %% [markdown]
# ### Finding the inflection point
#
# To find the pKa, we look for the inflection point on the curve, for which pH=pKa. This point corresponds to the point where the second derivative of pH as a function of Vs vanishes.
#
# The curve is given by the tables `pH` and `Vs` which have N values. The second derivative at point number `i` can be estimated using the formula
#
# $$\mathrm{second derivative}_i = \frac{ \mathrm{pH}_{i+1} - 2\mathrm{pH}_i + \mathrm{pH}_{i-1} }{ dV^2 }$$
#
# where $dV$ is the soda volume increment between two measurement points.
#
# Create a numpy array `second derivative` that contains the second derivative values ​​for all i between 1 and N-2.
#
# Then plot the second derivative of the pH as a function of the added volume, as well as the horizontal line that passes through y = 0.

# %%
# calculation of the second derivative

# plot of the second derivative as a function of pH

# %% [markdown]
# The second derivative is first negative, then positive. Find (using Python) the indices i1 and i2 of the points just before the sign change and just after this change.

# %%
# Determination of indices

# %% [markdown]
# Calculate the pKa as the average of the pH at points i1 and i2. You should find something close to 4.76.
# Calculate the corresponding volume of soda added `Vs0`, also using an average between the volumes at points i1 and i2.

# %%
# Calculation of pKa and Vs0

# %% [markdown]
# ### Final layout of the plot
#
# You will make a plot that looks like:
# ![](pKa.png)
#
# To do this, follow the following steps:
# - Draw the pH(Vs) curve again using crosses, and place a red circle on this curve at the pKa level.
# - Adjust the limits of the x and y axes to the min/max values ​​of the Vs and pH quantities.
# - Draw horizontal and vertical red dotted segments to connect this point to the axes.

# %%
# Final plot

# %% [markdown]
# Optional: this last calculation assumes that the zero ordinate is exactly in the middle between the points of index i1 and i2. This is not necessarily the case. You can improve the accuracy of the result by performing a linear interpolation between points i1 and i2: first determine the precise position `Vs0` of the zero of derivativeeSeconde using interpolation, and then calculate the `pKa` ​​with a second interpolation using i1, i2 and `Vs0`.

# %%
# ##########################################################################################
# delete this cell if you run this notebook outside of the CHIM2-ON1 distribution #
# ##########################################################################################

vID.end(cwd0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # ##########################################################################################
#       2 # delete this cell if you run this notebook outside of the CHIM2-ON1 distribution #
#       3 # ##########################################################################################
# ----> 5 vID.end(cwd0)
#
# NameError: name 'vID' is not defined
