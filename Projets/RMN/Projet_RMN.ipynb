# %% [markdown]
# <div style="text-align: center;">
# <span style="font-size: 22px; font-weight: bold;">Contrôle qualité des boissons alcoolisées</span><br>
# <span style="font-size: 16px; font-weight: normal;">Dosage de l'éthanol par RMN</span>
# </div>
# <br><br>
#
# <span style="margin-left: 40px;">
# Compte tenu du nombre croissant de fraudes, le contrôle qualité des produits de consommation est devenu essentiel. Nous vous proposons de développer un programme en Python permettant de vérifier la teneur en alcool de différentes boissons alcoolisées. Pour cela, vous analyserez des données issues de spectres de Résonance Magnétique Nucléaire (RMN) afin de doser la quantité d’éthanol présente dans plusieurs échantillons.
# <br><br>
# Vous devrez suivre les étapes suivantes :
# <ul>
#   <li><b>Étape 1</b> : Analyser le spectre de l’éthanol pur</li>
#   <li><b>Étape 2</b> : Établir la courbe de calibration de l’éthanol</li>
#   <li><b>Étape 3</b> : Doser l’éthanol dans les différentes boissons alcoolisées</li>
# </ul>
# </div>
#
# ### Informations et fichiers à votre dispositions :
# <ul>
#    <li><b>RMN</b> :<br>
#     Spéctromètre Bruker Avance 400 : 400.13 MHz<br>
#     Expérience 1D <sup>1</sup>H en conditions quantitative
#   </li>
#   <li><b>Éthanol</b> :<br>
#     Formule brute : C<sub>2</sub>H<sub>6</sub>O<br>
#     Masse molaire : 46,07 g/mol<br>
#     Masse volumique : 800 g/L (1 litre d’alcool pur pèse 800 grammes)
#   </li>
#   <li><b>Boissons à analyser</b> :<br>
#     Champagne : 12°, contient 12 % d’alcool (soit 12 % d’un litre d’alcool pur<br>
#     whisky : 40°<br>
#     Vermouth : 18°<br>
# </ul>
#
# <table style="font-size: 14px; border-collapse: collapse; width: auto; margin: auto;">
#   <tr>
#     <th style="border: 1px solid black; padding: 4px; text-align: center;">Fichiers</th>
#     <th style="border: 1px solid black; padding: 4px; text-align: center;">Description</th>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;"><code>EthanolNMRData_pur.dat</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;">Spectre RMN de l'éthanol pur</td>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;"><code>EthanolNMRData_calib.dat</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;">Spectres RMN de l'éthanol pur à différentes concentrations : 1 ; 2 ; 3 ; 5 et 10 mg/ml</td>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;"><code>EthanolNMRData_Champagne.dat</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;">Spectre RMN du champagne après préparation (dilution au 1/10 dans D<sub>2</sub>O)</td>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;"><code>EthanolNMRData_whisky.dat</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;">Spectre RMN du whisky après préparation (dilution au 1/100 dans D<sub>2</sub>O)</td>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;"><code>EthanolNMRData_vermouth.dat</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap;">Spectre RMN du vermouth après préparation (dilution au 1/100 dans D<sub>2</sub>O)</td>
#   </tr>
# </table>

# %% [markdown]
# ## <b>Étape 1</b> : Analyse du spectre de l'éthanol pur
#
# Dans un premier temps, vous devez effectuer l’analyse complète du spectre de l’éthanol pur. Pour cela, répondez aux différentes questions afin de compléter le tableau ci-dessous.
#
# <div style="text-align: center;">
#   <img src="tableau_attrib_vide.jpg" width="500" />
# </div>

# %% [markdown]
# ###  I. Lecture du fichier
#
# 1. Lire le fichier `EthanolNMRData_pur.dat` et afficher le spectre RMN de 0 à 10 ppm
#
# **Attenton :** Sur un spectre RMN, les déplacements chimiques se lisent de droite à gauche.

# %%
# 1.

# %% [markdown]
# 2. Créer une figure avec les diffèrents signaux observés.
# * À partir de la figure précédente, effectuez un zoom sur les différents signaux observés.
# * En déduire la multiplicité de chaque signal. Vous afficherez cette information en tant que label sur chaque zoom.
# * Proposer une attribution pour chaque signal. Vous afficherez cette information en tant que titre sur chaque zoom.
# * N'oubliez pas d'inclure tous les éléments nécessaires pour présenter proprement votre figure. Cela inclut les axes, les légendes, et tout autre détail permettant de rendre la figure claire et informative.
#
# Conserver les limites de chaque zoom. Elles vous serviront pour la suite des analyses.

# %%
# 2.

# %% [markdown]
# ###  II. Déplacement Chimique
#
# Vous devez déterminer la valeur du déplacement chimique pour chaque signal.
#
# La fonction `find_peaks` du module `scipy.signal` renvoie les indices des sommets des pics pour chaque signal (`listeIndices`) ainsi que l'intensité des pics (`peak_heights`). La syntaxe est la suivante :
#
# ```py
# listeIndices, peak_heights = find_peaks(x, height=   , ...)
# ```
# Où
# * x : fichier à analyser contenant des pics
# * height = : Hauteur minimale des pics à détecter
#
# NB : si la fonction `find_peaks` ne fonctionne pas en raison d'un problème d'installation, vous pouvez utiliser le bloc qui se trouve à la fin de ce projet.

# %% [markdown]
# 3. Trouver les sommets des pics sur le spectre de l'éthanol pur grâce à la fonction `find_peaks`. Créer une liste `ppmMax` contenant, pour chaque pic, le déplacement chimique du pic. Affichez la liste `ppmMax`.

# %%
# 3.

# %% [markdown]
# 4. Pour valider la liste `ppmMax`, reprenez le code utilisé pour générer les zooms de la figure de la question 3 et placez des lignes verticales rouges aux positions des déplacements chimiques des pics. Attribuer des labels pour chaque pic, indiquant le déplacement chimique (δ) en ppm avec 3 chiffres après la virgule.
#
# Vous pouvez utiliser la méthode « f-strings »
# ```py
# print(f"le déplacement chimique vaut {X:.2e}")
# ```
# Le texte doit être placé entre "..." avec f (format) devant. Entre les {...}, le `2` représente le nombre de chiffre significatif après la virgule, et le `e` ou `f`, représente le format, scientifique ou classique.

# %%
# 4.

# %% [markdown]
# 5. Calcul des déplacements chimiques pour chaque groupement de pics. Cela correspond à la moyenne des valeurs de déplacement chimique (δ) pour les pics dans chaque groupement. Afficher les résultats avec 3 chiffres après la virgule.

# %%
# 5.
# Out:
# le déplacement chimique de H₂O est 4.701 ppm
# le déplacement chimique de CH₂ éthanol est 3.535 ppm
# le déplacement chimique de CH₃ éthanol est 1.064 ppm

# %% [markdown]
# ###  III. Multiplicité et constante de couplage
#
# La multiplicité d’un signal RMN permet de déterminer le nombre de protons voisins du groupe étudié.
# Elle suit la règle du triangle de Pascal. De plus, l’écart entre les pics d’un même groupement est égal à la constante de couplage J, qui reflète l’interaction entre les groupes de protons voisins.
#
# Ci-dessous, un récapitulatif des motifs de signal les plus courants pour des noyaux de spin 1/2 :
#
# <table style="font-size: 14px; border-collapse: collapse; width: auto; margin: auto;">
#   <tr>
#     <th style="border: 1px solid black; padding: 4px; text-align: center;">Nombre de voisins</th>
#     <th style="border: 1px solid black; padding: 4px; text-align: center;">Multiplicité </th>
#     <th style="border: 1px solid black; padding: 4px; text-align: center;">Intensité des signaux</th>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;"><code>0</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">singulet</td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">1</td>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;"><code>1</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">doublet</td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">1 1</td
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;"><code>2</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">triplet</td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">1 2 1</td>
#   </tr>
#   <tr>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;"><code>3</code></td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">quadruplet</td>
#     <td style="border: 1px solid black; padding: 4px; white-space: nowrap; text-align: center;">1 3 3 1</td
#   </tr>
# </table>

# %% [markdown]
# 6. À partir des résultats obtenus avec la fonction `find_peaks`, récupérez la liste des intensités des pics.
# Pour chaque groupement de pics (c’est-à-dire chaque signal), vérifier si les intensités suivent les proportions prévues par la règle du triangle de Pascal. Commentez vos observations. Calculer la valeur de la constante de couplage quand elle existe. Afficher les résultats avec 2 chiffres après la virgule.
#
# **Attenton :** : le fichier `data` est un dictionnaire pouvant contenir plusieurs informations. Pour extraire la liste des valeurs, utiliser la ligne de commande suivante :
# ```py
# peak_heights = data['peak_heights']

# %%
# 6.

# %% [markdown]
# ###  IV. Integration
#
# On souhaite calculer l'aire sous chaque signal. Pour cela, utiliser La fonction `simpson` du module `scipy.integrate`. Il est nécessaire de connaitre les indices correspondant aux bornes de chaque signal à intégrer.
#
# 7. À l’aide de la figure ci-dessous, déterminez les indices correspondant aux bornes de chaque signal.
# Affichez ensuite ces bornes d’intégration à l’aide de cercles noirs sur les zooms des signaux de l’éthanol (en repartant du code utilisé pour générer la figure de la question 3).
#
# <img src="borne_int2.JPG" width = 400 />

# %%
# 7.

# %% [markdown]
# 8. Calculez l’aire sous chacun des signaux de l’éthanol. Normalisez ces aires en prenant celle du groupe CH<sub>2</sub> comme référence, fixée à 2. Affichez les résultats avec deux chiffres après la virgule.

# %%
# 8.

# %% [markdown]
# 9. À partir de l’ensemble des données précédemment obtenues, complétez le tableau ci-dessous selon le modèle fourni.
#
# <div style="text-align: center;">
#   <img src="tableau_attrib.JPG" width="500" />
# </div>

# %%
# 9.
from tabulate import tabulate

data = [
    [4.701, "singulet (1)","-","-","H\u2082O"],
    ["-","-","-","-","-"],
    ["-","-","-","-","-"],
]

table = tabulate(
    data,
    headers=["δ (ppm)", "multiplicité", "J (Hz)", "integration", "Attribution"],
    tablefmt="fancy_grid",
    colalign=("center","center","center", "center", "center"),
    floatfmt=".3f"
)

print(table)
# Out:
# ╒═══════════╤════════════════╤══════════╤═══════════════╤═══════════════╕
# │  δ (ppm)  │  multiplicité  │  J (Hz)  │  integration  │  Attribution  │
# ╞═══════════╪════════════════╪══════════╪═══════════════╪═══════════════╡
# │   4.701   │  singulet (1)  │    -     │       -       │      H₂O      │
# ├───────────┼────────────────┼──────────┼───────────────┼───────────────┤
# │     -     │       -        │    -     │       -       │       -       │
# ├───────────┼────────────────┼──────────┼───────────────┼───────────────┤
# │     -     │       -        │    -     │       -       │       -       │
# ╘═══════════╧════════════════╧══════════╧═══════════════╧═══════════════╛

# %% [markdown]
# ## <b>Étape 2</b> : Établir la courbe de calibration de l'éthanol
#
# Le fichier `EthanolNMRData_calib.dat` contient les spectres de l'éthanol à diffèrentes concentrations : <b>1 ; 2 ; 3 ; 5 et 10 mg/ml</b>
#
# 10. Lire le fichier et afficher les spectres RMN pour les régions d'interet.

# %%
# 10.

# %% [markdown]
# 11. Calculez l’aire de chaque signal.. Plutôt que d’utiliser les indices comme précédemment, vous pouvez directement sélectionner les plages de déplacement chimique (en ppm) correspondant aux régions à intégrer dans le spectre.

# %%
# 11.

# %% [markdown]
# 12. Déterminez les équations des courbes d’étalonnage pour chacun des signaux. Tracez ensuite ces courbes en représentant l’aire en fonction de la concentration.

# %%
# 12.

# %% [markdown]
# ## <b>Étape 3</b> : Doser l'éthanol dans les différentes boissons alcoolisées
#
# Pour valider les courbes d’étalonnage, vous allez doser l’éthanol dans trois échantillons tests dont le pourcentage d’alcool est connu :
# <ul>
#     Champagne : 12°, contient 12 % d’alcool (soit 12 % d’un litre d’alcool pur)<br>
#     Vermouth : 18°<br>
#     whisky : 40°<br>
# </ul>
#
# 13. Lisez les fichiers correspondant à ces échantillons et affichez leurs spectres RMN. Créez un graphique pour chaque spectre en mettant en évidence les zones d’intérêt (signaux de l’éthanol).

# %%
# 13.

# %% [markdown]
# 14. Calculez les aires des zones d’intérêt accessibles dans le spectre de l’échantillon de Champagne. Projetez ensuite ces valeurs sur vos courbes d’étalonnage et vérifiez si elles se situent dans la gamme des concentrations utilisées pour l’étalonnage. En déduire la concentration en éthanol, puis calculez le pourcentage d’alcool contenu dans cet échantillon.

# %%
# 14.

# %% [markdown]
# 15. Déterminez le pourcentage d’alcool pour les deux autres échantillons (whisky et vermouth).

# %%
# 15.

# %% [markdown]
# NB : si la fonction `find_peaks` ne fonctionne pas suite à un problème d'installation, vous pouvez les remplacer par le bloc suivant :
# ```py
# ppm2 = ppm.copy()
# I2 = I.copy()
# ppm2[I<1e5] = NaN
# I2[I<1e5] = NaN
# from itertools import groupby
# result = [list(v) for k,v in groupby(I2,np.isfinite) if k]
# N = len(result)
# listeIndices = []
# for i in range(N):
#     maxpic = max(result[i])
#     listeIndices.append( where(I==maxpic)[0][0] )
# ```
